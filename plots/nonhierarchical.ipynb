# %%
from plot import *
save_plots = True
folder = "2026_07_12"
import os

# %% [markdown]
# # Plot non-hierarchical experiments
#
# This notebook goes over plotting dual gaps and out-of-sample performance for non-hierarchical problems.
#
# ## Inventory

# %%
large_lam = False
if save_plots:
    plot_newsvendor_bound_gap(large_lam, os.path.join(folder, 'newsvendor_gap_gammasmall.pdf'))
else:
    plot_newsvendor_bound_gap(large_lam)

# %%
large_lam = True
if save_plots:
    plot_newsvendor_bound_gap(large_lam, os.path.join(folder, 'newsvendor_gap_gammalarge.pdf'))
else:
    plot_newsvendor_bound_gap(large_lam)

# %% [markdown]
# We now look at runtimes.

# %%
large_gamma = True
if save_plots:
    plot_newsvendor_runtimes(large_gamma, os.path.join(folder, 'newsvendor_runtime_gammalarge.pdf'))
else:
    plot_newsvendor_runtimes(large_gamma)

# %% [markdown]
# Out-of-sample performance.

# %%
print_oos_performance('inventory')

# %% [markdown]
# ## Risk-adverse inventory

# %%
large_lam = False
if save_plots:
    plot_riskadverse_newsvendor_bound_gap(large_lam, os.path.join(folder, 'riskadverse_newsvendor_gap_gammasmall.pdf'))
else:
    plot_riskadverse_newsvendor_bound_gap(large_lam)

# %% [markdown]
# ## Hydro-thermal

# %%
large_lam = False
if save_plots:
    plot_hydro_bound_gap(large_lam, os.path.join(folder, 'hydro_gap_gammasmall.pdf'), hide_legend=large_lam)
    large_lam = True
    plot_hydro_bound_gap(large_lam, os.path.join(folder, 'hydro_gap_gammalarge.pdf'), hide_legend=large_lam)
else:
    plot_hydro_bound_gap(large_lam, hide_legend=large_lam)
    large_lam = True
    plot_hydro_bound_gap(large_lam, hide_legend=large_lam)

# %%
largegamma = 0
print_optimality_gap(largegamma)

# %%
print_oos_performance('hydro')
